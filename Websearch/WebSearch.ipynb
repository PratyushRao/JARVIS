# %%
# !pip uninstall -y duckduckgo_search
# !pip install ddgs
# Out:
# Found existing installation: duckduckgo_search 8.1.1
# Uninstalling duckduckgo_search-8.1.1:
#   Successfully uninstalled duckduckgo_search-8.1.1
# ...

# %%
;from ddgs import DDGS

with DDGS() as ddgs:
    results = ddgs.text("Best movie to watch 2025", max_results=5)

for r in results:
    print("Title:", r["title"])
    print("URL:", r["href"])
    print("Snippet:", r["body"])
    print("-" * 60)
# Out:
# Title: Rotten Tomatoes Best New Movies of 2025, Ranked by Tomatometer | Rotten Tomatoes
# URL: https://editorial.rottentomatoes.com/guide/best-new-movies/
# Snippet: 4 days ago - Discover every Certified Fresh movie of the year, including ' Predator: Badlands ,' 'Bugonia,' 'Mistress Dispeller', and more.
# ------------------------------------------------------------
# Title: IMDb Best 20 Movies of 2025
# URL: https://www.imdb.com/list/ls566987552/
# Snippet: List your movie, TV & celebrity picks. 28 titles · Sort byList order · List order · Alphabetical · IMDb rating · Popularity · Number of ratings · Release date · Runtime · Date added · 20252h 17mR84Metascore · 7.6 (310K)RateMark as watched · Trying to leave their troubled lives behind, twin brothers return to their hometown to start again, only to discover that an even greater evil is waiting to welcome them back.DirectorRyan CooglerStarsMiles CatonSaul WilliamsAndrene Ward-Hammond ·
# ...
